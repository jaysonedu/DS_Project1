# %% [markdown]
# # Smoke Test: Load Newest Raw Files
#
# Load the most recently acquired raw file from each source and print shapes.
# Run data acquirers first if directories are empty.

# %%
import sys
from pathlib import Path

# Add project root so "from src.acquire" works
ROOT = Path.cwd()
while ROOT != ROOT.parent and not (ROOT / "pyproject.toml").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

# %%
from src.acquire._loaders import load_all_newest

results = load_all_newest()
for source, (path, df) in results.items():
    if path is None or df is None:
        print(f"{source}: no file found")
    else:
        print(f"{source}: {path.name} -> shape {df.shape}")
# Out:
# zillow: zillow_zhvi_20260212_165121.csv -> shape (26307, 321)
# nyc_crime: nyc_crime_20260212_165453.parquet -> shape (577674, 36)
# acs: acs_2023_20260212_165918.parquet -> shape (33772, 12)
# fred: fred_20260212_170235.csv -> shape (197, 3)

# %%
import pandas as pd
from pathlib import Path

ROOT = Path.cwd()
while ROOT != ROOT.parent and not (ROOT / "pyproject.toml").exists():
    ROOT = ROOT.parent

path = ROOT / "data" / "raw" / "acs" / "acs_2023_20260212_165918.parquet"
df = pd.read_parquet(path)
df.to_csv(ROOT / "data" / "raw" / "acs" / "acs_2023.csv", index=False)

# %%
import pandas as pd
from pathlib import Path

ROOT = Path.cwd()
while ROOT != ROOT.parent and not (ROOT / "pyproject.toml").exists():
    ROOT = ROOT.parent

path = ROOT / "data" / "raw" / "nyc_crime" / "nyc_crime_20260212_165453.parquet"
df = pd.read_parquet(path)
df.to_csv(ROOT / "data" / "raw" / "nyc_crime" / "nyc_crime_2023.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 9
#       6     ROOT = ROOT.parent
#       8 crime_dir = ROOT / "data" / "raw" / "nyc_crime_20260212_165453.parquet"
# ----> 9 parquet_file = max(crime_dir.glob("*.parquet"), key=lambda p: p.stat().st_mtime)
#      10 df = pd.read_parquet(parquet_file)
#      11 df.to_csv(crime_dir / "nyc_crime.csv", index=False)
#
# ValueError: max() iterable argument is empty
